# %% [markdown]
# # Level 01 · Meeting 01 — Mengenal AI / AI, EKKA, and Your First Program
# **Content version / Versi konten:** 1.0.0 · **Runtime:** Python 3 (CPU)
#
# > Pilih **File → Save a copy in Drive** sebelum mengedit. / Choose **File → Save a copy in Drive** before editing.

# %% [markdown]
# ## Tujuan / Objectives
# - Memetakan input → proses → output. / Map input → process → output.
# - Menjalankan dan mengubah program Python. / Run and modify a Python program.
# - Memeriksa klaim, bukan hanya keluaran. / Inspect claims, not just outputs.

# %% [markdown]
# ## Setup dependency
# Pertemuan ini hanya memakai Python standard library; tidak ada instalasi. / This meeting only uses the Python standard library; no installation is needed.

# %%
import sys, random
SEED = 2026
random.seed(SEED)
print('Python', sys.version.split()[0], '| seed', SEED)

# %% [markdown]
# ## Contoh terbimbing / Guided example
# Prediksi skor sebelum menjalankan sel. / Predict the score before running the cell.

# %%
name = 'Alya'
correct, wrong, blank = 17, 3, 5
score = 4 * correct - wrong
print(name, score)

# %% [markdown]
# ## TODO — Latihan / Exercise
# Ubah nilai lalu hitung skor 20 benar, 4 salah, 1 kosong. / Compute 20 correct, 4 wrong, 1 blank.

# %%
# TODO: replace the values, predict, then run
correct, wrong, blank = 20, 4, 1
student_score = 4 * correct - wrong
assert student_score == 76
print(student_score)

# %% [markdown]
# ## Challenge
# Tulis ringkasan tiga baris tentang input, proses, dan output program skor. / Print a three-line summary of the scoring program's input, process, and output.

# %%
print('Input: counts of correct and wrong answers')
print('Process: 4 * correct - wrong')
print('Output: competition score')

# %% [markdown]
# ## Pembahasan dan solusi / Discussion and solutions
# Hasil latihan adalah 76 karena `4 × 20 − 4 = 76`. Jawaban challenge boleh berbeda selama ketiga bagian jelas. / The exercise result is 76 because `4 × 20 − 4 = 76`. Challenge wording may differ if all three parts are clear.

# %% [markdown]
# ## Refleksi hasil / Result reflection
# 1. Apa prediksimu sebelum Run? / What did you predict before Run?
# 2. Apa satu perbedaan program aturan dan ML? / Name one difference between a rule-based program and ML.
# 3. Salin satu pesan galat yang kamu pahami. / Copy one error message you now understand.
