# %% [markdown]
# # Modul 1: Dasar Python, Variable, dan Expression
#
# Level 1, versi 2.0.0

# %% [markdown]
# ## Petunjuk penggunaan
#
# 1. Simpan salinan notebook ke Google Drive.
# 2. Kerjakan cell dari atas ke bawah.
# 3. Pada blok prediksi, tulis dugaan sebelum menjalankan kode.
# 4. Isi cell latihan tanpa melihat completed notebook.
# 5. Jalankan cell pemeriksaan setelah menyelesaikan latihan.

# %% [markdown]
# ## Hasil belajar
#
# - Menjalankan code cell dengan urutan yang benar
# - Menggunakan variable dan empat data type dasar
# - Menghitung expression dan melakukan type conversion
# - Menerima input dan menampilkan output dengan f-string

# %% [markdown]
# ## Pemeriksaan awal
#
# Jalankan cell berikut untuk menyiapkan feedback otomatis.

# %%
def check_equal(label, actual, expected):
    if actual == expected:
        print(f"OK: {label}")
    else:
        print(f"Belum tepat: {label}")
        print(f"  Diperoleh: {actual!r}")
        print(f"  Diharapkan: {expected!r}")


def check_call(label, function, args, expected):
    if not callable(function):
        print(f"Belum tepat: {label}. Function belum dibuat")
        return
    try:
        actual = function(*args)
    except Exception as error:
        print(f"Belum tepat: {label}. Pemanggilan menghasilkan {type(error).__name__}")
        return
    check_equal(label, actual, expected)


print("Pemeriksaan awal selesai. Python siap digunakan.")

# %% [markdown]
# ## Prediksi → jalankan → amati
#
# Prediksi nilai yang muncul setelah cell kedua dijalankan dua kali.

# %%
score = 70
print(score)

# %%
score = score + 5
print(score)

# %% [markdown]
# Amati bahwa source code tetap sama, tetapi state berubah setelah setiap eksekusi.

# %% [markdown]
# ## Guided example: literal, variable, dan expression
#
# Jalankan contoh secara berurutan.

# %%
item_name = "Buku tulis"
unit_price = 8500
quantity = 4
subtotal = unit_price * quantity
print(f"{quantity} {item_name}: Rp{subtotal}")

# %% [markdown]
# ### Eksperimen data type
#
# Ubah satu literal, lalu perhatikan hasil `type()`.

# %%
values = [12, 12.0, "12", True]
for value in values:
    print(value, type(value))

# %% [markdown]
# ### Eksperimen operator
#
# Prediksi setiap output sebelum menjalankan cell.

# %%
print(17 / 5)
print(17 // 5)
print(17 % 5)
print(2 ** 3)
print(4 + 3 * 2)
print((4 + 3) * 2)

# %% [markdown]
# ### Eksperimen type conversion

# %%
quantity_text = "6"
quantity_number = int(quantity_text)
price_number = float("7500.50")
print(quantity_text * 2)
print(quantity_number * 2)
print(price_number)

# %% [markdown]
# ### Contoh input
#
# Cell ini bersifat interaktif dan tidak dijalankan oleh validator.

# %%
user_name = input("Nama: ")
age = int(input("Umur: "))
print(f"{user_name} berumur {age} tahun")

# %% [markdown]
# ### Contoh error yang disengaja
#
# Jalankan satu per satu dan baca jenis error yang muncul.

# %%
print(unknown_name)

# %%
print("Umur: " + 16)

# %% [markdown]
# ### Latihan
#
# Simpan `total_seconds = 125`. Buat `full_minutes` dan `remaining_seconds` menggunakan `//` dan `%`.

# %%
total_seconds = 125
full_minutes = total_seconds // 60
remaining_seconds = total_seconds % 60

# %%
check_equal("menit penuh", globals().get("full_minutes"), 2)

# %%
check_equal("detik tersisa", globals().get("remaining_seconds"), 5)

# %% [markdown]
# ### Latihan
#
# Ubah `quantity_text = "6"` menjadi `int` bernama `quantity`, lalu hitung `double_quantity`.

# %%
quantity_text = "6"
quantity = int(quantity_text)
double_quantity = quantity * 2

# %%
check_equal("type conversion", globals().get("quantity"), 6)

# %%
check_equal("hasil setelah conversion", globals().get("double_quantity"), 12)

# %% [markdown]
# ### Latihan
#
# Hitung expression `(8 + 4) * 3` dan simpan ke `expression_result`.

# %%
expression_result = (8 + 4) * 3

# %%
check_equal("prioritas operator", globals().get("expression_result"), 36)

# %% [markdown]
# ### Latihan
#
# Buat `student_name = "Rani"` dan `score = 88`, lalu simpan f-string `Rani mendapat 88` ke `summary`.

# %%
student_name = "Rani"
score = 88
summary = f"{student_name} mendapat {score}"

# %%
check_equal("formatted output", globals().get("summary"), "Rani mendapat 88")

# %% [markdown]
# ## Mini project: kalkulator tagihan
#
# Hitung subtotal, diskon tetap Rp10.000, total pembayaran, dan receipt satu baris.

# %% [markdown]
# ### Latihan
#
# Gunakan `customer_name = "Nadia"`, `unit_price = 25000`, `quantity = 3`, dan `fixed_discount = 10000`. Buat `subtotal`, `total_payment`, serta `receipt` dengan format `Nadia membayar Rp65000`.

# %%
customer_name = "Nadia"
unit_price = 25000
quantity = 3
fixed_discount = 10000
subtotal = unit_price * quantity
total_payment = subtotal - fixed_discount
receipt = f"{customer_name} membayar Rp{total_payment}"

# %%
check_equal("subtotal project", globals().get("subtotal"), 75000)

# %%
check_equal("total project", globals().get("total_payment"), 65000)

# %% [markdown]
# ## Checkpoint
#
# Jalankan seluruh pemeriksaan. Pastikan setiap label menampilkan `OK`.

# %% [markdown]
# ## Refleksi singkat
#
# Konsep mana yang paling sering membuat prediksi berbeda dari output? Jelaskan perubahan state atau data type yang menyebabkannya.
